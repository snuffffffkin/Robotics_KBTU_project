# %% [markdown]
# <a href="https://colab.research.google.com/github/snuffffffkin/Robotics_KBTU_project/blob/main/faceID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Setting

# %% [markdown]
# 1.1 Install dependencies

# %%
! pip install tensorflow opencv-python matplotlib

# %% [markdown]
# 1.2 Import dependencies

# %%
import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf

# %% [markdown]
# 1.3 Set GPU growth

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %%
for gpu in gpus:
  print(gpu)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# 1.4 Create Folder Strustures

# %%
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
os.makedirs(POS_PATH)
os.makedirs(NEG_PATH)
os.makedirs(ANC_PATH)

# %% [markdown]
# 2. Collect POS and ANCH
# ******************************************************************************

# %% [markdown]
# 2.1 Untar labelled faces in the wild dataset

# %% [markdown]
# done

# %%
os.listdir()
# Out:
# ['.config', 'data', 'sample_data']

# %% [markdown]
# 2.2 Collect positive and ancor classes

# %%
# !ls /content/
# Out:
# data  sample_data

# %%
cap = cv2.VideoCapture(3)
while cap.isOpened():
  ret, frame = cap.read()

  cv2.imshow('Image Collection', frame)

  if cv2.watKey(1) & 0XFF == ord('q'):
    break
cap.release()
cv2.destroyAllWindows()

# %%
from google.colab import drive
import shutil
import os

# 1️⃣ Mount Google Drive
drive.mount('/content/drive')

# 2️⃣ Set folder paths
DRIVE_FOLDER = '/content/drive/MyDrive/negative'  # your folder in Drive
negative = '/content/data/negative'                # where it will be copied in Colab

# 3️⃣ Copy folder to Colab
shutil.copytree(DRIVE_FOLDER, negative, dirs_exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/data/negative'
